# %% [markdown]
# # Clean
#
# This notebook loads your assembled data and prepares it for modeling.
#
# The final output is a `sup` that is fully ready for modeling and analysis.
#
# Here's what happens in this notebook:
# - We fill gaps in the data using reasonable assumptions
# - We prepare the data for further analysis by marking clusters
# - We process sales validity information
# - We run our own sales scrutiny heuristic to make sure we only use trustworthy sales that reflect market value
#
# These operations are necessary for modeling, but nevertheless inject a certain amount of subjectivity into the model, which is why we keep the results of the **Clean** notebook separate from those produced in the **Assemble** notebook.

# %%
# Change these as desired

# The slug of the locality you are currently working on
locality = "us-md-baltimorecity"

# Whether to print out a lot of stuff (can help with debugging) or stay mostly quiet
verbose = True

# Clear previous state for this notebook and start fresh
clear_checkpoints = True

# %% [markdown]
# # 1. Basic setup

# %%
import init_notebooks
init_notebooks.setup_environment()
# Out:
# Environment setup completed.

# %%
# import a bunch of stuff
from openavmkit.pipeline import (
    init_notebook,
    from_checkpoint,
    delete_checkpoints,
    write_checkpoint,
    read_pickle,
    load_settings,
    examine_sup,
    fill_unknown_values_sup,
    process_sales,
    mark_ss_ids_per_model_group_sup,
    mark_horizontal_equity_clusters_per_model_group_sup,
    run_sales_scrutiny_per_model_group_sup,
    write_notebook_output_sup
)

# %%
init_notebook(locality)
# Out:
# locality = us-md-baltimorecity
# base path = /Users/gregmiller/Documents/openavmkit/openavmkit/notebooks/pipeline
# current path = /Users/gregmiller/Documents/openavmkit/openavmkit/notebooks/pipeline/data/us-md-baltimorecity

# %%
if clear_checkpoints:
    delete_checkpoints("2-clean")

# %% [markdown]
# # 2. Load data

# %%
settings = load_settings()

# %%
# load the data
sales_univ_pair = read_pickle("out/1-assemble-sup")

# %%
examine_sup(sales_univ_pair, settings)
# Out:
# EXAMINING UNIVERSE...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_land_value                 Float64      219,315   93%    236,505  100%
# exempt_land_value               Float64       16,452    7%    236,471  100%
# geom_aspect_ratio               float64      236,505  100%    236,505  100%
# geom_rectangularity_num         Float64      236,487  100%    236,505  100%
# geom_vertices                    int64       236,492  100%    236,505  100%
# housing_growth_past_5_years     Float64      232,806   98%    236,328  100%
# land_area_gis_delta_percent     Float64      141,996   60%    235,609  100%
# land_area_gis_delta_sqft        Float64      142,892   60%    236,505  100%
# land_area_gis_sqft              float64      236,505  100%    236,505  100%
# land_area_given_sqft            Float64      141,996   60%    142,892   60%
# land_area_sqft                  Float64      235,609  100%    236,505  100%
# latitude                        float64      236,505  100%    236,505  100%
# longitude                       float64      236,505  100%    236,505  100%
# median_household_income         Float64      235,479  100%    236,328  100%
# population_density              Float64      236,328  100%    236,328  100%
# population_gr...h_past_5_years  Float64      235,371  100%    236,328  100%
# transmission_line_distance      Float64      233,812   99%    234,959   99%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_geom_complex                 boolean        3,636    2%    236,505  100%                            [False, True]
# is_geom_elongated                 bool        97,242   41%    236,505  100%                            [False, True]
# is_geom_irregular               boolean      102,078   43%    236,505  100%                            [False, True]
# is_geom_triangular                bool         2,044    1%    236,505  100%                            [False, True]
# is_vacant                         bool       105,510   45%    236,505  100%                            [True, False]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# block                            string      236,505  100%    236,505  100%                                    5,547
# census_block                     string      236,505  100%    236,505  100%                                    9,163
# census_block_group               string      236,505  100%    236,505  100%                                      642
# census_tract                     string      236,505  100%    236,505  100%                                      218
# city                             string      236,505  100%    236,505  100%                            ['baltimore']
# lbcs_site_desc                   string      220,510   93%    220,510   93%                                        4
# lot                              string      236,471  100%    236,471  100%                                    3,080
# neighborhood                     string      235,850  100%    235,850  100%                                      281
# parcel_use_code                  string      236,471  100%    236,471  100%                                       12
# parcel_use_desc                  string      157,418   67%    157,418   67%                                       12
# police_district                  string      235,816  100%    235,816  100%                                       10
# risk_disaster                    string      236,318  100%    236,318  100%                                        5
# risk_flood                       string      234,215   99%    234,215   99%                                        4
# section                          string      236,471  100%    236,471  100%                                       67
# ward                             string      236,505  100%    236,505  100%                                       29
# zip                              string      236,505  100%    236,505  100%                                       41
# zoning                           string      236,504  100%    236,504  100%                                       71
# zoning_desc                      string      236,502  100%    236,502  100%                                       45
# zoning_subtype                   string      236,502  100%    236,502  100%                                       14
# zoning_type                      string      236,502  100%    236,502  100%                                        7
#
# ============================== ========== ========== ===== ========== ===== ========================================
#          IMPROVEMENT
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_impr_value                 Float64      208,668   88%    236,505  100%
# bldg_age_years                  Float64      179,593   76%    179,593   76%
# bldg_area_finished_sqft         Float64      217,389   92%    217,389   92%
# bldg_area_footprint_sqft        Float64      216,205   91%    216,205   91%
# bldg_count                      Float64      216,205   91%    236,505  100%
# bldg_rooms_bath                 Float64      135,688   57%    137,139   58%
# bldg_rooms_bed                  Float64       81,787   35%     82,768   35%
# bldg_stories                    Float64        8,786    4%      8,786    4%
# bldg_units                      Float64          266    0%    236,505  100%
# bldg_year_built                 Float64      179,593   76%    179,593   76%
# exempt_impr_value               Float64        7,842    3%    236,471  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_bldg_vacant                   object      236,471  100%    236,471  100%                              [True, nan]
# is_usps_vacant                    bool       236,505  100%    236,505  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# bldg_class                       string      155,045   66%    155,045   66%                                       10
# bldg_style                       string      107,998   46%    107,998   46%                                      133
# lbcs_activity_desc               string      220,510   93%    220,510   93%                                        6
# lbcs_function_desc               string      220,510   93%    220,510   93%                                        6
# lbcs_structure_desc              string      219,980   93%    219,980   93%                                        5
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_market_value               Float64      219,397   93%    236,505  100%
# credit_city_homestead           Float64          221    0%    233,674   99%
# credit_state_homestead          Float64        5,355    2%    236,471  100%
# sale_age_days                    Int64       236,502  100%    236,502  100%
# sale_month                      float64      236,502  100%    236,502  100%
# sale_price                      Float64      168,569   71%    236,505  100%
# sale_quarter                    float64      236,502  100%    236,502  100%
# sale_year                       float64      236,502  100%    236,502  100%
# zestimate                       Float64      125,240   53%    125,240   53%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_vacant                         bool       105,510   45%    236,505  100%                            [True, False]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assess_grp                       string      236,471  100%    236,471  100%                    ['2', <NA>, '3', '1']
# assessor                         string      236,384  100%    236,384  100%                                       46
# exempt_code                      string      236,470  100%    236,470  100%                                       81
# exempt_type                      string           32    0%         32    0%                              [<NA>, 'E']
# key                              string      236,505  100%    236,505  100%                                  236,505
# lbcs_ownership_desc              string      199,628   84%    199,628   84%                                       10
# mail_city                        string      170,271   72%    170,271   72%                                    2,980
# mail_state                       string      170,414   72%    170,414   72%                                       87
# mail_zip                         string      221,077   93%    221,077   93%                                   22,951
# model_group                      object      236,505  100%    236,505  100%                                        6
# owner_vs_renter                  string      236,505  100%    236,505  100%                          ['N', 'H', 'D']
# ownership_mode                   string      207,412   88%    207,412   88%                    ['F', <NA>, 'L', '3']
# parcel_value_type                string      236,505  100%    236,505  100%                               ['MARKET']
# sale_date                      datetime64[ns]    236,502  100%    236,502  100%                                   15,443
# sale_year_month                  object      236,505  100%    236,505  100%                                    1,258
# sale_year_quarter                object      236,505  100%    236,505  100%                                      507
# status_owner                     string      236,471  100%    236,471  100%                    ['N', 'H', <NA>, 'D']
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# address                          object      229,593   97%    229,593   97%                                  226,825
# address_mail                     object      236,471  100%    236,471  100%                                  175,679
# bldg_area_fin..._sqft_inferred    bool       236,505  100%    236,505  100%                            [True, False]
# dist_to_educational             float64      236,505  100%    236,505  100%                                  218,696
# dist_to_educa...ins_university  float64      236,505  100%    236,505  100%                                  222,140
# dist_to_educa...rsity_maryland  float64      236,505  100%    236,505  100%                                  222,185
# dist_to_educa..._for_the_blind  float64      236,505  100%    236,505  100%                                  222,163
# dist_to_educa...ate_university  float64      236,505  100%    236,505  100%                                  222,247
# dist_to_educa...ltimore_county  float64      236,505  100%    236,505  100%                                  222,363
# dist_to_golf_courses            float64      236,505  100%    236,505  100%                                  222,110
# dist_to_golf_...rk_golf_course  float64      236,505  100%    236,505  100%                                  222,253
# dist_to_golf_...rk_golf_course  float64      236,505  100%    236,505  100%                                  222,289
# dist_to_golf_...nt_golf_course  float64      236,505  100%    236,505  100%                                  222,196
# dist_to_parks                   float64      236,505  100%    236,505  100%                                  216,400
# dist_to_parks...p_clifton_park  float64      236,505  100%    236,505  100%                                  222,149
# dist_to_parks...burn_arboretum  float64      236,505  100%    236,505  100%                                  222,325
# dist_to_parks...ruid_hill_park  float64      236,505  100%    236,505  100%                                  222,285
# dist_to_parks..._/_leakin_park  float64      236,505  100%    236,505  100%                                  221,921
# dist_to_parks...rring_run_park  float64      236,505  100%    236,505  100%                                  221,962
# dist_to_transportation          float64      236,505  100%    236,505  100%                                  220,815
# dist_to_trans...heast_corridor  float64      236,505  100%    236,505  100%                                  222,017
# dist_to_trans..._unnamed_route  float64      236,505  100%    236,505  100%                                  222,187
# dist_to_water_bodies            float64      236,505  100%    236,505  100%                                  221,815
# dist_to_water...p_curtis_creek  float64      236,505  100%    236,505  100%                                  222,030
# dist_to_water...patapsco_river  float64      236,505  100%    236,505  100%                                  222,240
# dist_to_water...rthwest_harbor  float64      236,505  100%    236,505  100%                                  221,686
# dist_to_water...patapsco_river  float64      236,505  100%    236,505  100%                                  222,173
# geometry                        geometry     236,505  100%    236,505  100%                                  222,588
# key2                             object      155,045   66%    155,045   66%                                  154,875
# zoning_url                       object      236,502  100%    236,502  100%                                        4
#
# EXAMINING SALES...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# sale_age_days                    Int64        54,118  100%     54,118  100%
# sale_month                      float64       54,118  100%     54,118  100%
# sale_price                      Float64       54,122  100%     54,124  100%
# sale_price_time_adj             Float64       54,122  100%     54,123  100%
# sale_quarter                    float64       54,118  100%     54,118  100%
# sale_year                       float64       54,118  100%     54,118  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# vacant_sale                      object          599    1%     54,124  100%                            [False, True]
# valid_for_land_ratio_study        bool           599    1%     54,124  100%                            [False, True]
# valid_for_ratio_study             bool        32,735   60%     54,124  100%                            [True, False]
# valid_sale                       object       54,124  100%     54,124  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# key                              string       54,124  100%     54,124  100%                                   48,117
# key_sale                         string       54,124  100%     54,124  100%                                   54,124
# sale_date                      datetime64[ns]     54,118  100%     54,118  100%                                    1,326
# sale_year_month                  object       54,124  100%     54,124  100%                                       64
# sale_year_quarter                object       54,124  100%     54,124  100%                                       23
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# sale_grantor                     object       54,116  100%     54,116  100%                                   39,446
# sale_record                     float64       54,124  100%     54,124  100%                          [1.0, 2.0, 3.0]

# %% [markdown]
# # 3. Fill unknowns
#
# Modeling functions are unable to process null data, so you need to fill them in somehow.
# The goal is to **eliminate all gaps in your data,** at least for fields you intend to turn into modeling variables.
#
# Consult the documentation for more details and best practices on filling unknown values.

# %%
# Fill holes in the data with sensible defaults
sales_univ_pair = fill_unknown_values_sup(sales_univ_pair, settings)
# Out:
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)
# /Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/cleaning.py:369: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df[field].fillna(False)

# %%
# Look at the data and make sure it makes sense
examine_sup(sales_univ_pair, settings)
# Out:
# EXAMINING UNIVERSE...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_land_value                 Float64      219,315   93%    236,505  100%
# exempt_land_value               Float64       16,452    7%    236,471  100%
# geom_aspect_ratio               float64      236,505  100%    236,505  100%
# geom_rectangularity_num         Float64      236,487  100%    236,505  100%
# geom_vertices                    int64       236,492  100%    236,505  100%
# housing_growth_past_5_years     Float64      232,983   99%    236,505  100%
# land_area_gis_delta_percent     Float64      141,996   60%    235,609  100%
# land_area_gis_delta_sqft        Float64      142,892   60%    236,505  100%
# land_area_gis_sqft              float64      236,505  100%    236,505  100%
# land_area_given_sqft            Float64      141,996   60%    142,892   60%
# land_area_sqft                  Float64      235,609  100%    236,505  100%
# latitude                        float64      236,505  100%    236,505  100%
# longitude                       float64      236,505  100%    236,505  100%
# median_household_income         Float64      235,656  100%    236,505  100%
# population_density              Float64      236,505  100%    236,505  100%
# population_gr...h_past_5_years  Float64      235,548  100%    236,505  100%
# transmission_line_distance      Float64      235,358  100%    236,505  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_geom_complex                 boolean        3,636    2%    236,505  100%                            [False, True]
# is_geom_elongated                 bool        97,242   41%    236,505  100%                            [False, True]
# is_geom_irregular               boolean      102,078   43%    236,505  100%                            [False, True]
# is_geom_triangular                bool         2,044    1%    236,505  100%                            [False, True]
# is_vacant                         bool       105,510   45%    236,505  100%                            [True, False]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# block                            string      236,505  100%    236,505  100%                                    5,547
# census_block                     string      236,505  100%    236,505  100%                                    9,163
# census_block_group               string      236,505  100%    236,505  100%                                      642
# census_tract                     string      236,505  100%    236,505  100%                                      218
# city                             string      236,505  100%    236,505  100%                            ['baltimore']
# lbcs_site_desc                   string      236,505  100%    236,505  100%                                        4
# lot                              string      236,505  100%    236,505  100%                                    3,080
# neighborhood                     string      236,505  100%    236,505  100%                                      281
# parcel_use_code                  string      236,505  100%    236,505  100%                                       12
# parcel_use_desc                  string      236,505  100%    236,505  100%                                       12
# police_district                  string      236,505  100%    236,505  100%                                       10
# risk_disaster                    string      236,505  100%    236,505  100%                                        5
# risk_flood                       string      236,505  100%    236,505  100%                                        4
# section                          string      236,505  100%    236,505  100%                                       67
# ward                             string      236,505  100%    236,505  100%                                       29
# zip                              string      236,505  100%    236,505  100%                                       41
# zoning                           string      236,505  100%    236,505  100%                                       71
# zoning_desc                      string      236,505  100%    236,505  100%                                       45
# zoning_subtype                   string      236,505  100%    236,505  100%                                       14
# zoning_type                      string      236,505  100%    236,505  100%                                        7
#
# ============================== ========== ========== ===== ========== ===== ========================================
#          IMPROVEMENT
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_impr_value                 Float64      208,668   88%    236,505  100%
# bldg_age_years                  Float64      179,593   76%    236,505  100%
# bldg_area_finished_sqft         Float64      217,389   92%    236,505  100%
# bldg_area_footprint_sqft        Float64      216,205   91%    236,505  100%
# bldg_count                      Float64      216,205   91%    236,505  100%
# bldg_rooms_bath                 Float64      135,688   57%    236,505  100%
# bldg_rooms_bed                  Float64       81,787   35%    236,505  100%
# bldg_stories                    Float64        8,786    4%    236,505  100%
# bldg_units                      Float64          266    0%    236,505  100%
# bldg_year_built                 Float64      179,593   76%    236,505  100%
# exempt_impr_value               Float64        7,842    3%    236,505  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_bldg_vacant                   object      236,471  100%    236,505  100%                            [True, False]
# is_usps_vacant                    bool       236,505  100%    236,505  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# bldg_class                       string      236,505  100%    236,505  100%                                       10
# bldg_style                       string      236,505  100%    236,505  100%                                      133
# lbcs_activity_desc               string      236,505  100%    236,505  100%                                        6
# lbcs_function_desc               string      236,505  100%    236,505  100%                                        6
# lbcs_structure_desc              string      236,505  100%    236,505  100%                                        5
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_market_value               Float64      219,397   93%    236,505  100%
# credit_city_homestead           Float64          221    0%    236,505  100%
# credit_state_homestead          Float64        5,355    2%    236,505  100%
# sale_age_days                    Int64       236,502  100%    236,502  100%
# sale_month                      float64      236,502  100%    236,502  100%
# sale_price                      Float64      168,569   71%    236,505  100%
# sale_quarter                    float64      236,502  100%    236,502  100%
# sale_year                       float64      236,502  100%    236,502  100%
# zestimate                       Float64      125,240   53%    125,240   53%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_vacant                         bool       105,510   45%    236,505  100%                            [True, False]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assess_grp                       string      236,505  100%    236,505  100%                  ['2', '<NA>', '3', '1']
# assessor                         string      236,505  100%    236,505  100%                                       46
# exempt_code                      string      236,505  100%    236,505  100%                                       81
# exempt_type                      string      236,505  100%    236,505  100%                            ['<NA>', 'E']
# key                              string      236,505  100%    236,505  100%                                  236,505
# lbcs_ownership_desc              string      236,505  100%    236,505  100%                                       10
# mail_city                        string      236,505  100%    236,505  100%                                    2,980
# mail_state                       string      236,505  100%    236,505  100%                                       87
# mail_zip                         string      236,505  100%    236,505  100%                                   22,951
# model_group                      object      236,505  100%    236,505  100%                                        6
# owner_vs_renter                  string      236,505  100%    236,505  100%                          ['N', 'H', 'D']
# ownership_mode                   string      236,505  100%    236,505  100%               ['F', 'UNKNOWN', 'L', '3']
# parcel_value_type                string      236,505  100%    236,505  100%                               ['MARKET']
# sale_date                      datetime64[ns]    236,502  100%    236,502  100%                                   15,443
# sale_year_month                  object      236,505  100%    236,505  100%                                    1,258
# sale_year_quarter                object      236,505  100%    236,505  100%                                      507
# status_owner                     string      236,505  100%    236,505  100%                  ['N', 'H', '<NA>', 'D']
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# address                          object      229,593   97%    229,593   97%                                  226,825
# address_mail                     object      236,471  100%    236,471  100%                                  175,679
# bldg_area_fin..._sqft_inferred    bool       236,505  100%    236,505  100%                            [True, False]
# dist_to_educational             float64      236,505  100%    236,505  100%                                  218,696
# dist_to_educa...ins_university  float64      236,505  100%    236,505  100%                                  222,140
# dist_to_educa...rsity_maryland  float64      236,505  100%    236,505  100%                                  222,185
# dist_to_educa..._for_the_blind  float64      236,505  100%    236,505  100%                                  222,163
# dist_to_educa...ate_university  float64      236,505  100%    236,505  100%                                  222,247
# dist_to_educa...ltimore_county  float64      236,505  100%    236,505  100%                                  222,363
# dist_to_golf_courses            float64      236,505  100%    236,505  100%                                  222,110
# dist_to_golf_...rk_golf_course  float64      236,505  100%    236,505  100%                                  222,253
# dist_to_golf_...rk_golf_course  float64      236,505  100%    236,505  100%                                  222,289
# dist_to_golf_...nt_golf_course  float64      236,505  100%    236,505  100%                                  222,196
# dist_to_parks                   float64      236,505  100%    236,505  100%                                  216,400
# dist_to_parks...p_clifton_park  float64      236,505  100%    236,505  100%                                  222,149
# dist_to_parks...burn_arboretum  float64      236,505  100%    236,505  100%                                  222,325
# dist_to_parks...ruid_hill_park  float64      236,505  100%    236,505  100%                                  222,285
# dist_to_parks..._/_leakin_park  float64      236,505  100%    236,505  100%                                  221,921
# dist_to_parks...rring_run_park  float64      236,505  100%    236,505  100%                                  221,962
# dist_to_transportation          float64      236,505  100%    236,505  100%                                  220,815
# dist_to_trans...heast_corridor  float64      236,505  100%    236,505  100%                                  222,017
# dist_to_trans..._unnamed_route  float64      236,505  100%    236,505  100%                                  222,187
# dist_to_water_bodies            float64      236,505  100%    236,505  100%                                  221,815
# dist_to_water...p_curtis_creek  float64      236,505  100%    236,505  100%                                  222,030
# dist_to_water...patapsco_river  float64      236,505  100%    236,505  100%                                  222,240
# dist_to_water...rthwest_harbor  float64      236,505  100%    236,505  100%                                  221,686
# dist_to_water...patapsco_river  float64      236,505  100%    236,505  100%                                  222,173
# geometry                        geometry     236,505  100%    236,505  100%                                  222,588
# key2                             object      155,045   66%    155,045   66%                                  154,875
# zoning_url                       object      236,502  100%    236,502  100%                                        4
#
# EXAMINING SALES...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# sale_age_days                    Int64        54,118  100%     54,118  100%
# sale_month                      float64       54,118  100%     54,118  100%
# sale_price                      Float64       54,122  100%     54,124  100%
# sale_price_time_adj             Float64       54,122  100%     54,123  100%
# sale_quarter                    float64       54,118  100%     54,118  100%
# sale_year                       float64       54,118  100%     54,118  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# vacant_sale                       bool           599    1%     54,124  100%                            [False, True]
# valid_for_land_ratio_study        bool           599    1%     54,124  100%                            [False, True]
# valid_for_ratio_study             bool        32,735   60%     54,124  100%                            [True, False]
# valid_sale                        bool        54,124  100%     54,124  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# key                              string       54,124  100%     54,124  100%                                   48,117
# key_sale                         string       54,124  100%     54,124  100%                                   54,124
# sale_date                        object       54,124  100%     54,124  100%                                    1,326
# sale_year_month                  object       54,124  100%     54,124  100%                                       64
# sale_year_quarter                object       54,124  100%     54,124  100%                                       23
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# sale_grantor                     object       54,116  100%     54,116  100%                                   39,446
# sale_record                     float64       54,124  100%     54,124  100%                          [1.0, 2.0, 3.0]

# %% [markdown]
# # 4. Clustering
#
# We cluster all similar properties and give each cluster a unique ID.
# Later, we'll use these ID's whenever we want to run a horizontal equity study.

# %%
settings = load_settings()
sales_univ_pair = from_checkpoint("2-clean-00-horizontal-equity", mark_horizontal_equity_clusters_per_model_group_sup,
    {
        "sup": sales_univ_pair,
        "settings": settings,
        "verbose": verbose
    }
)
# Out:
# Marking horizontal equity clusters...
# Processing model group: apartments
# --> crunching on location, 153 clusters
# --> crunching on is_vacant, 153 clusters
# ----> Processing batch 0-100 of 153
# ----> Processing batch 100-153 of 153
# --> crunching on land_area_sqft, 153 clusters
# ----> Processing batch 0-100 of 153
# ----> Processing batch 100-153 of 153
# --> crunching on bldg_area_finished_sqft, 165 clusters
# ----> Processing batch 0-100 of 165
# ----> Processing batch 100-165 of 165
# --> crunching on bldg_quality_num, 173 clusters
# ----> Processing batch 0-100 of 173
# ----> Processing batch 100-173 of 173
# --> crunching on bldg_condition_num, 173 clusters
# ----> Processing batch 0-100 of 173
# ----> Processing batch 100-173 of 173
# --> crunching on bldg_age_years, 173 clusters
# ----> Processing batch 0-100 of 173
# ----> Processing batch 100-173 of 173
# Processing model group: rowhome
# --> crunching on location, 241 clusters
# --> crunching on is_vacant, 241 clusters
# ----> Processing batch 0-100 of 241
# ----> 0/241, 0% clustering on EASTERWOOD, field = is_vacant, size = 747
# ----> Processing batch 100-200 of 241
# ----> 100/241, 41% clustering on ASHBURTON, field = is_vacant, size = 127
# ----> Processing batch 200-241 of 241
# ----> 200/241, 83% clustering on WALTHERSON, field = is_vacant, size = 475
# --> crunching on land_area_sqft, 440 clusters
# ----> Processing batch 0-100 of 440
# ----> 0/440, 0% clustering on EASTERWOOD_1, field = land_area_sqft, size = 628
# ----> Processing batch 100-200 of 440
# ----> 100/440, 23% clustering on PATTERSON PLACE_1, field = land_area_sqft, size = 129
# ----> Processing batch 200-300 of 440
# ----> 200/440, 45% clustering on PARKWAY_1, field = land_area_sqft, size = 161
# ----> Processing batch 300-400 of 440
# ----> 300/440, 68% clustering on COLDSPRING_0, field = land_area_sqft, size = 92
# ----> Processing batch 400-440 of 440
# --> crunching on bldg_area_finished_sqft, 827 clusters
# ----> Processing batch 0-100 of 827
# ----> 0/827, 0% clustering on EASTERWOOD_1_1148.0, field = bldg_area_finished_sqft, size = 315
# ----> Processing batch 100-200 of 827
# ----> Processing batch 200-300 of 827
# ----> 200/827, 24% clustering on PATTERSON PARK NEIGHBORHOOD_1_5427.561946678063, field = bldg_area_finished_sqft, size = 283
# ----> Processing batch 300-400 of 827
# ----> 300/827, 36% clustering on YALE HEIGHTS_0_174240.0, field = bldg_area_finished_sqft, size = 235
# ----> Processing batch 400-500 of 827
# ----> 400/827, 48% clustering on PARKLANE_0_740520.0, field = bldg_area_finished_sqft, size = 100
# ----> Processing batch 500-600 of 827
# ----> 500/827, 60% clustering on EAST BALTIMORE MIDWAY_0_1301.5, field = bldg_area_finished_sqft, size = 94
# ----> Processing batch 600-700 of 827
# ----> Processing batch 700-800 of 827
# ----> Processing batch 800-827 of 827
# ----> 800/827, 97% clustering on HUNTING RIDGE_0_3296.5, field = bldg_area_finished_sqft, size = 76
# --> crunching on bldg_quality_num, 1506 clusters
# ----> Processing batch 0-100 of 1506
# ----> Processing batch 100-200 of 1506
# ----> Processing batch 200-300 of 1506
# ----> Processing batch 300-400 of 1506
# ----> Processing batch 400-500 of 1506
# ----> Processing batch 500-600 of 1506
# ----> Processing batch 600-700 of 1506
# ----> Processing batch 700-800 of 1506
# ----> Processing batch 800-900 of 1506
# ----> Processing batch 900-1000 of 1506
# ----> Processing batch 1000-1100 of 1506
# ----> Processing batch 1100-1200 of 1506
# ----> Processing batch 1200-1300 of 1506
# ----> Processing batch 1300-1400 of 1506
# ----> Processing batch 1400-1500 of 1506
# ----> Processing batch 1500-1506 of 1506
# --> crunching on bldg_condition_num, 1506 clusters
# ----> Processing batch 0-100 of 1506
# ----> Processing batch 100-200 of 1506
# ----> Processing batch 200-300 of 1506
# ----> Processing batch 300-400 of 1506
# ----> Processing batch 400-500 of 1506
# ----> Processing batch 500-600 of 1506
# ----> Processing batch 600-700 of 1506
# ----> Processing batch 700-800 of 1506
# ----> Processing batch 800-900 of 1506
# ----> Processing batch 900-1000 of 1506
# ----> Processing batch 1000-1100 of 1506
# ----> Processing batch 1100-1200 of 1506
# ----> Processing batch 1200-1300 of 1506
# ----> Processing batch 1300-1400 of 1506
# ----> Processing batch 1400-1500 of 1506
# ----> Processing batch 1500-1506 of 1506
# --> crunching on bldg_age_years, 1506 clusters
# ----> Processing batch 0-100 of 1506
# ----> 0/1506, 0% clustering on EASTERWOOD_1_1148.0_1246.6681367144433, field = bldg_age_years, size = 158
# ----> Processing batch 100-200 of 1506
# ----> 100/1506, 7% clustering on MOUNT CLARE_1_34848000.0_41079.208333333336, field = bldg_age_years, size = 262
# ----> Processing batch 200-300 of 1506
# ----> 200/1506, 13% clustering on OTTERBEIN_1_8384.778862406347_93921.43147208123, field = bldg_age_years, size = 145
# ----> Processing batch 300-400 of 1506
# ----> 300/1506, 20% clustering on BEREA_1_103.53201651903215_1770.3225806451612, field = bldg_age_years, size = 126
# ----> Processing batch 400-500 of 1506
# ----> 400/1506, 27% clustering on HIGHLANDTOWN_0_37949472.0_1459.0, field = bldg_age_years, size = 218
# ----> Processing batch 500-600 of 1506
# ----> Processing batch 600-700 of 1506
# ----> Processing batch 700-800 of 1506
# ----> 700/1506, 46% clustering on TOWANDA-GRANTLEY_1_43560.0_1347.3111633847398, field = bldg_age_years, size = 98
# ----> Processing batch 800-900 of 1506
# ----> 800/1506, 53% clustering on ROLAND PARK_0_4356.0_3908.0, field = bldg_age_years, size = 51
# ----> Processing batch 900-1000 of 1506
# ----> 900/1506, 60% clustering on HILLEN_0_324900.0_5560.0, field = bldg_age_years, size = 165
# ----> Processing batch 1000-1100 of 1506
# ----> 1000/1506, 66% clustering on WOODMERE_0_1710.0_1178.0, field = bldg_age_years, size = 240
# ----> Processing batch 1100-1200 of 1506
# ----> Processing batch 1200-1300 of 1506
# ----> Processing batch 1300-1400 of 1506
# ----> 1300/1506, 86% clustering on CEDONIA_0_1977.0_2252.0, field = bldg_age_years, size = 62
# ----> Processing batch 1400-1500 of 1506
# ----> 1400/1506, 93% clustering on CURTIS BAY_1_170.7493918784749_1766.2481923874639, field = bldg_age_years, size = 103
# ----> Processing batch 1500-1506 of 1506
# Processing model group: single_family
# --> crunching on location, 107 clusters
# --> crunching on is_vacant, 107 clusters
# ----> Processing batch 0-100 of 107
# ----> Processing batch 100-107 of 107
# ----> 100/107, 93% clustering on TEN HILLS, field = is_vacant, size = 311
# --> crunching on land_area_sqft, 186 clusters
# ----> Processing batch 0-100 of 186
# ----> Processing batch 100-186 of 186
# ----> 100/186, 54% clustering on LAKE EVESHAM_1, field = land_area_sqft, size = 56
# --> crunching on bldg_area_finished_sqft, 334 clusters
# ----> Processing batch 0-100 of 334
# ----> Processing batch 100-200 of 334
# ----> 100/334, 30% clustering on FALLSTAFF_0_20280.0, field = bldg_area_finished_sqft, size = 215
# ----> Processing batch 200-300 of 334
# ----> 200/334, 60% clustering on MID-GOVANS_0_255566928.0, field = bldg_area_finished_sqft, size = 38
# ----> Processing batch 300-334 of 334
# --> crunching on bldg_quality_num, 568 clusters
# ----> Processing batch 0-100 of 568
# ----> Processing batch 100-200 of 568
# ----> Processing batch 200-300 of 568
# ----> Processing batch 300-400 of 568
# ----> Processing batch 400-500 of 568
# ----> Processing batch 500-568 of 568
# --> crunching on bldg_condition_num, 568 clusters
# ----> Processing batch 0-100 of 568
# ----> Processing batch 100-200 of 568
# ----> Processing batch 200-300 of 568
# ----> Processing batch 300-400 of 568
# ----> Processing batch 400-500 of 568
# ----> Processing batch 500-568 of 568
# --> crunching on bldg_age_years, 568 clusters
# ----> Processing batch 0-100 of 568
# ----> Processing batch 100-200 of 568
# ----> 100/568, 18% clustering on ROLAND PARK_1_1243.1343572247388_2603.835476918812, field = bldg_age_years, size = 57
# ----> Processing batch 200-300 of 568
# ----> 200/568, 35% clustering on CHESWOLDE_0_9997.0_2000.0, field = bldg_age_years, size = 183
# ----> Processing batch 300-400 of 568
# ----> 300/568, 53% clustering on CEDARCROFT_0_11246.0_2196.0, field = bldg_age_years, size = 47
# ----> Processing batch 400-500 of 568
# ----> 400/568, 70% clustering on OVERLEA_0_7497.0_1376.0, field = bldg_age_years, size = 52
# ----> Processing batch 500-568 of 568
# ----> 500/568, 88% clustering on MORRELL PARK_0_115900.0_1328.0, field = bldg_age_years, size = 61
# Processing model group: commercial
# --> crunching on location, 263 clusters
# --> crunching on is_vacant, 263 clusters
# ----> Processing batch 0-100 of 263
# ----> Processing batch 100-200 of 263
# ----> Processing batch 200-263 of 263
# --> crunching on land_area_sqft, 324 clusters
# ----> Processing batch 0-100 of 324
# ----> Processing batch 100-200 of 324
# ----> 100/324, 31% clustering on CANTON INDUSTRIAL AREA, field = land_area_sqft, size = 76
# ----> Processing batch 200-300 of 324
# ----> Processing batch 300-324 of 324
# ----> 300/324, 93% clustering on BROOKLYN_0, field = land_area_sqft, size = 150
# --> crunching on bldg_area_finished_sqft, 475 clusters
# ----> Processing batch 0-100 of 475
# ----> Processing batch 100-200 of 475
# ----> 100/475, 21% clustering on OLIVER_164.77207040572995, field = bldg_area_finished_sqft, size = 68
# ----> Processing batch 200-300 of 475
# ----> 200/475, 42% clustering on EDGEWOOD_1_27286.55589888197, field = bldg_area_finished_sqft, size = 15
# ----> Processing batch 300-400 of 475
# ----> Processing batch 400-475 of 475
# --> crunching on bldg_quality_num, 614 clusters
# ----> Processing batch 0-100 of 614
# ----> Processing batch 100-200 of 614
# ----> Processing batch 200-300 of 614
# ----> Processing batch 300-400 of 614
# ----> Processing batch 400-500 of 614
# ----> Processing batch 500-600 of 614
# ----> Processing batch 600-614 of 614
# --> crunching on bldg_condition_num, 614 clusters
# ----> Processing batch 0-100 of 614
# ----> Processing batch 100-200 of 614
# ----> Processing batch 200-300 of 614
# ----> Processing batch 300-400 of 614
# ----> Processing batch 400-500 of 614
# ----> Processing batch 500-600 of 614
# ----> Processing batch 600-614 of 614
# --> crunching on bldg_age_years, 614 clusters
# ----> Processing batch 0-100 of 614
# ----> Processing batch 100-200 of 614
# ----> Processing batch 200-300 of 614
# ----> 200/614, 33% clustering on CARE_1_7274.0_34531.898014440434, field = bldg_age_years, size = 74
# ----> Processing batch 300-400 of 614
# ----> 300/614, 49% clustering on CENTRAL PARK HEIGHTS_56418.041647531216_1567.5129290079926, field = bldg_age_years, size = 27
# ----> Processing batch 400-500 of 614
# ----> Processing batch 500-600 of 614
# ----> Processing batch 600-614 of 614
# Processing model group: industrial
# --> crunching on location, 78 clusters
# --> crunching on is_vacant, 78 clusters
# ----> Processing batch 0-78 of 78
# ----> 0/78, 0% clustering on BRIDGEVIEW/GREENLAWN, field = is_vacant, size = 22
# --> crunching on land_area_sqft, 83 clusters
# ----> Processing batch 0-83 of 83
# --> crunching on bldg_area_finished_sqft, 106 clusters
# ----> Processing batch 0-100 of 106
# ----> 0/106, 0% clustering on BRIDGEVIEW/GREENLAWN_1, field = bldg_area_finished_sqft, size = 22
# ----> Processing batch 100-106 of 106
# ----> 100/106, 94% clustering on SAINT PAUL_1_371.37901006237155, field = bldg_area_finished_sqft, size = 40
# --> crunching on bldg_quality_num, 124 clusters
# ----> Processing batch 0-100 of 124
# ----> Processing batch 100-124 of 124
# --> crunching on bldg_condition_num, 124 clusters
# ----> Processing batch 0-100 of 124
# ----> Processing batch 100-124 of 124
# --> crunching on bldg_age_years, 124 clusters
# ----> Processing batch 0-100 of 124
# ----> 0/124, 0% clustering on BRIDGEVIEW/GREENLAWN_1_185925.66381766382, field = bldg_age_years, size = 22
# ----> Processing batch 100-124 of 124
# ----> 100/124, 81% clustering on FAIRFIELD AREA_275292.312186105_8256.199052132702, field = bldg_age_years, size = 69
#
# Marking LAND horizontal equity clusters...
# Processing model group: apartments
# --> crunching on location, 153 clusters
# --> crunching on land_area_sqft, 166 clusters
# ----> Processing batch 0-100 of 166
# ----> Processing batch 100-166 of 166
# --> crunching on geom_rectangularity_num, 178 clusters
# ----> Processing batch 0-100 of 178
# ----> Processing batch 100-178 of 178
# --> crunching on geom_aspect_ratio, 186 clusters
# ----> Processing batch 0-100 of 186
# ----> Processing batch 100-186 of 186
# --> crunching on elevation_mean, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# --> crunching on slope_mean, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# --> crunching on noise_mean, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# --> crunching on is_geom_complex, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# --> crunching on is_geom_irregular, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# --> crunching on osm_is_waterfront, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# --> crunching on osm_on_golf_course, 196 clusters
# ----> Processing batch 0-100 of 196
# ----> Processing batch 100-196 of 196
# Processing model group: rowhome
# --> crunching on location, 241 clusters
# --> crunching on land_area_sqft, 313 clusters
# ----> Processing batch 0-100 of 313
# ----> 0/313, 0% clustering on EASTERWOOD_AREA OF MINIMAL FLOOD HAZARD, field = land_area_sqft, size = 747
# ----> Processing batch 100-200 of 313
# ----> Processing batch 200-300 of 313
# ----> 200/313, 64% clustering on CYLBURN_AREA OF MINIMAL FLOOD HAZARD, field = land_area_sqft, size = 174
# ----> Processing batch 300-313 of 313
# ----> 300/313, 96% clustering on WESTGATE_AREA OF MINIMAL FLOOD HAZARD, field = land_area_sqft, size = 383
# --> crunching on geom_rectangularity_num, 521 clusters
# ----> Processing batch 0-100 of 521
# ----> 0/521, 0% clustering on EASTERWOOD_AREA OF MINIMAL FLOOD HAZARD_1162.0, field = geom_rectangularity_num, size = 380
# ----> Processing batch 100-200 of 521
# ----> 100/521, 19% clustering on MILTON-MONTFORD_AREA OF MINIMAL FLOOD HAZARD_801.0, field = geom_rectangularity_num, size = 395
# ----> Processing batch 200-300 of 521
# ----> 200/521, 38% clustering on HANLON-LONGWOOD_AREA OF MINIMAL FLOOD HAZARD_147015008.0, field = geom_rectangularity_num, size = 322
# ----> Processing batch 300-400 of 521
# ----> 300/521, 58% clustering on BELAIR-EDISON_AREA OF MINIMAL FLOOD HAZARD_73180800.0, field = geom_rectangularity_num, size = 2978
# ----> Processing batch 400-500 of 521
# ----> 400/521, 77% clustering on RICHNOR SPRINGS_AREA OF MINIMAL FLOOD HAZARD_2831400.0, field = geom_rectangularity_num, size = 158
# ----> Processing batch 500-521 of 521
# --> crunching on geom_aspect_ratio, 926 clusters
# ----> Processing batch 0-100 of 926
# ----> 0/926, 0% clustering on EASTERWOOD_AREA OF MINIMAL FLOOD HAZARD_1162.0_0.989023299562206, field = geom_aspect_ratio, size = 190
# ----> Processing batch 100-200 of 926
# ----> Processing batch 200-300 of 926
# ----> 200/926, 22% clustering on CARE_AREA OF MINIMAL FLOOD HAZARD_46696320.0_0.9902584031515677, field = geom_aspect_ratio, size = 168
# ----> Processing batch 300-400 of 926
# ----> 300/926, 32% clustering on WINCHESTER_AREA OF MINIMAL FLOOD HAZARD_1330.0_0.9896124245696427, field = geom_aspect_ratio, size = 147
# ----> Processing batch 400-500 of 926
# ----> 400/926, 43% clustering on ASHBURTON_AREA OF MINIMAL FLOOD HAZARD_1615.0_0.8873763612402787, field = geom_aspect_ratio, size = 34
# ----> Processing batch 500-600 of 926
# ----> Processing batch 600-700 of 926
# ----> 600/926, 65% clustering on ARLINGTON_AREA OF MINIMAL FLOOD HAZARD_4268880.0_0.9458363536345251, field = geom_aspect_ratio, size = 216
# ----> Processing batch 700-800 of 926
# ----> 700/926, 76% clustering on CAMERON VILLAGE_AREA OF MINIMAL FLOOD HAZARD_54034.04024724025_0.9416759780999322, field = geom_aspect_ratio, size = 121
# ----> Processing batch 800-900 of 926
# ----> 800/926, 86% clustering on ORCHARD RIDGE_AREA OF MINIMAL FLOOD HAZARD_1611.0_0.9335567013697649, field = geom_aspect_ratio, size = 40
# ----> Processing batch 900-926 of 926
# --> crunching on elevation_mean, 1669 clusters
# ----> Processing batch 0-100 of 1669
# ----> Processing batch 100-200 of 1669
# ----> Processing batch 200-300 of 1669
# ----> Processing batch 300-400 of 1669
# ----> Processing batch 400-500 of 1669
# ----> Processing batch 500-600 of 1669
# ----> Processing batch 600-700 of 1669
# ----> Processing batch 700-800 of 1669
# ----> Processing batch 800-900 of 1669
# ----> Processing batch 900-1000 of 1669
# ----> Processing batch 1000-1100 of 1669
# ----> Processing batch 1100-1200 of 1669
# ----> Processing batch 1200-1300 of 1669
# ----> Processing batch 1300-1400 of 1669
# ----> Processing batch 1400-1500 of 1669
# ----> Processing batch 1500-1600 of 1669
# ----> Processing batch 1600-1669 of 1669
# --> crunching on slope_mean, 1669 clusters
# ----> Processing batch 0-100 of 1669
# ----> Processing batch 100-200 of 1669
# ----> Processing batch 200-300 of 1669
# ----> Processing batch 300-400 of 1669
# ----> Processing batch 400-500 of 1669
# ----> Processing batch 500-600 of 1669
# ----> Processing batch 600-700 of 1669
# ----> Processing batch 700-800 of 1669
# ----> Processing batch 800-900 of 1669
# ----> Processing batch 900-1000 of 1669
# ----> Processing batch 1000-1100 of 1669
# ----> Processing batch 1100-1200 of 1669
# ----> Processing batch 1200-1300 of 1669
# ----> Processing batch 1300-1400 of 1669
# ----> Processing batch 1400-1500 of 1669
# ----> Processing batch 1500-1600 of 1669
# ----> Processing batch 1600-1669 of 1669
# --> crunching on noise_mean, 1669 clusters
# ----> Processing batch 0-100 of 1669
# ----> Processing batch 100-200 of 1669
# ----> Processing batch 200-300 of 1669
# ----> Processing batch 300-400 of 1669
# ----> Processing batch 400-500 of 1669
# ----> Processing batch 500-600 of 1669
# ----> Processing batch 600-700 of 1669
# ----> Processing batch 700-800 of 1669
# ----> Processing batch 800-900 of 1669
# ----> Processing batch 900-1000 of 1669
# ----> Processing batch 1000-1100 of 1669
# ----> Processing batch 1100-1200 of 1669
# ----> Processing batch 1200-1300 of 1669
# ----> Processing batch 1300-1400 of 1669
# ----> Processing batch 1400-1500 of 1669
# ----> Processing batch 1500-1600 of 1669
# ----> Processing batch 1600-1669 of 1669
# --> crunching on is_geom_complex, 1669 clusters
# ----> Processing batch 0-100 of 1669
# ----> 0/1669, 0% clustering on EASTERWOOD_AREA OF MINIMAL FLOOD HAZARD_1162.0_0.989023299562206_5.777683082369902, field = is_geom_complex, size = 95
# ----> Processing batch 100-200 of 1669
# ----> 100/1669, 6% clustering on BARRE CIRCLE_AREA OF MINIMAL FLOOD HAZARD_871.0_0.9983173881744799_8.822022928480376, field = is_geom_complex, size = 20
# ----> Processing batch 200-300 of 1669
# ----> 200/1669, 12% clustering on RIDGELY'S DELIGHT_AREA OF MINIMAL FLOOD HAZARD_4356.0_0.9509408671101489_10.04270631292396, field = is_geom_complex, size = 47
# ----> Processing batch 300-400 of 1669
# ----> 300/1669, 18% clustering on JONESTOWN_AREA OF MINIMAL FLOOD HAZARD_26876520.0_0.9797930111442192_4.935960591163586, field = is_geom_complex, size = 20
# ----> Processing batch 400-500 of 1669
# ----> 400/1669, 24% clustering on BUTCHERS HILL_AREA OF MINIMAL FLOOD HAZARD_743.5_0.9987085165127876_5.195146113263745, field = is_geom_complex, size = 103
# ----> Processing batch 500-600 of 1669
# ----> 500/1669, 30% clustering on SAINT JOSEPHS_AREA OF MINIMAL FLOOD HAZARD_2570040.0_0.9537635229887147_4.859045995643827, field = is_geom_complex, size = 111
# ----> Processing batch 600-700 of 1669
# ----> 600/1669, 36% clustering on EDMONDSON VILLAGE_AREA OF MINIMAL FLOOD HAZARD_1600.0_0.9898487618946421_5.1097946202531, field = is_geom_complex, size = 185
# ----> Processing batch 700-800 of 1669
# ----> 700/1669, 42% clustering on LUCILLE PARK_AREA OF MINIMAL FLOOD HAZARD_12196.0_0.9543672427152079_8.823599939210347, field = is_geom_complex, size = 29
# ----> Processing batch 800-900 of 1669
# ----> 800/1669, 48% clustering on CENTRAL PARK HEIGHTS_AREA OF MINIMAL FLOOD HAZARD_1528.0_0.9879882378915088_6.727578968970498, field = is_geom_complex, size = 300
# ----> Processing batch 900-1000 of 1669
# ----> 900/1669, 54% clustering on TUSCANY-CANTERBURY_0.2 PCT ANNUAL CHANCE FLOOD HAZARD_5413.247792562451_0.7767584657079423_2.8753650455108173, field = is_geom_complex, size = 19
# ----> Processing batch 1000-1100 of 1669
# ----> 1000/1669, 60% clustering on ORIGINAL NORTHWOOD_AREA OF MINIMAL FLOOD HAZARD_13068.0_0.9943444848687701_5.824590290507571, field = is_geom_complex, size = 20
# ----> Processing batch 1100-1200 of 1669
# ----> 1100/1669, 66% clustering on WOODMERE_AREA OF MINIMAL FLOOD HAZARD_23674.0_0.9937989355992884_11.162712501091365, field = is_geom_complex, size = 95
# ----> Processing batch 1200-1300 of 1669
# ----> 1200/1669, 72% clustering on KERNEWOOD_AREA OF MINIMAL FLOOD HAZARD_3794946.0_0.9995256546786859_10.873505647589708, field = is_geom_complex, size = 15
# ----> Processing batch 1300-1400 of 1669
# ----> 1300/1669, 78% clustering on KENILWORTH PARK_AREA OF MINIMAL FLOOD HAZARD_1604.0_0.9935293602416468_8.532152752852417, field = is_geom_complex, size = 15
# ----> Processing batch 1400-1500 of 1669
# ----> 1400/1669, 84% clustering on WALTHERSON_AREA OF MINIMAL FLOOD HAZARD_319511776.0_0.9860283804433906_6.948350723230253, field = is_geom_complex, size = 59
# ----> Processing batch 1500-1600 of 1669
# ----> 1500/1669, 90% clustering on GRACELAND PARK_AREA OF MINIMAL FLOOD HAZARD_1600.0_0.9950769531216329_6.7027686812691245, field = is_geom_complex, size = 43
# ----> Processing batch 1600-1669 of 1669
# ----> 1600/1669, 96% clustering on MORRELL PARK_AREA OF MINIMAL FLOOD HAZARD_740014720.0_0.9822416251886061_17.50249517872165, field = is_geom_complex, size = 163
# --> crunching on is_geom_irregular, 1672 clusters
# ----> Processing batch 0-100 of 1672
# ----> 0/1672, 0% clustering on EASTERWOOD_AREA OF MINIMAL FLOOD HAZARD_1162.0_0.989023299562206_5.777683082369902_0, field = is_geom_irregular, size = 95
# ----> Processing batch 100-200 of 1672
# ----> Processing batch 200-300 of 1672
# ----> Processing batch 300-400 of 1672
# ----> 300/1672, 18% clustering on JONESTOWN_0.2 PCT ANNUAL CHANCE FLOOD HAZARD_2221.0_0.9225973164751827_0, field = is_geom_irregular, size = 16
# ----> Processing batch 400-500 of 1672
# ----> 400/1672, 24% clustering on BUTCHERS HILL_AREA OF MINIMAL FLOOD HAZARD_743.5_0.9892348348238423_4.3834794790177884_0, field = is_geom_irregular, size = 103
# ----> Processing batch 500-600 of 1672
# ----> 500/1672, 30% clustering on CARROLL-SOUTH HILTON_AREA OF MINIMAL FLOOD HAZARD_135502.0_0.999523543798351_4.7949160153884_0, field = is_geom_irregular, size = 80
# ----> Processing batch 600-700 of 1672
# ----> 600/1672, 36% clustering on EDMONDSON VILLAGE_AREA OF MINIMAL FLOOD HAZARD_1600.0_0.9996891912941803_5.574525145750279_0, field = is_geom_irregular, size = 185
# ----> Processing batch 700-800 of 1672
# ----> Processing batch 800-900 of 1672
# ----> 800/1672, 48% clustering on CENTRAL PARK HEIGHTS_AREA OF MINIMAL FLOOD HAZARD_1528.0_0.9549148891841535_28.668567111099158_0, field = is_geom_irregular, size = 300
# ----> Processing batch 900-1000 of 1672
# ----> Processing batch 1000-1100 of 1672
# ----> 1000/1672, 60% clustering on NEW NORTHWOOD_AREA OF MINIMAL FLOOD HAZARD_2109.0_0.9651776183321674_10.782944599490719_0, field = is_geom_irregular, size = 150
# ----> Processing batch 1100-1200 of 1672
# ----> Processing batch 1200-1300 of 1672
# ----> Processing batch 1300-1400 of 1672
# ----> 1300/1672, 78% clustering on RICHNOR SPRINGS_AREA OF MINIMAL FLOOD HAZARD_1382.5_0.9690056888585804_3.7124068576246843_0, field = is_geom_irregular, size = 40
# ----> Processing batch 1400-1500 of 1672
# ----> 1400/1672, 84% clustering on WALTHERSON_AREA OF MINIMAL FLOOD HAZARD_2554.0_0.9407000962146355_7.479567017769969_0, field = is_geom_irregular, size = 59
# ----> Processing batch 1500-1600 of 1672
# ----> 1500/1672, 90% clustering on BREWERS HILL_AREA OF MINIMAL FLOOD HAZARD_962.0_0.9883562949253104_10.06977839586595_0, field = is_geom_irregular, size = 98
# ----> Processing batch 1600-1672 of 1672
# ----> 1600/1672, 96% clustering on VIOLETVILLE_AREA OF MINIMAL FLOOD HAZARD_474368384.0_0.9841695257330663_11.908316679976268_0, field = is_geom_irregular, size = 96
# --> crunching on osm_is_waterfront, 2083 clusters
# ----> Processing batch 0-100 of 2083
# ----> Processing batch 100-200 of 2083
# ----> Processing batch 200-300 of 2083
# ----> Processing batch 300-400 of 2083
# ----> Processing batch 400-500 of 2083
# ----> Processing batch 500-600 of 2083
# ----> Processing batch 600-700 of 2083
# ----> Processing batch 700-800 of 2083
# ----> Processing batch 800-900 of 2083
# ----> Processing batch 900-1000 of 2083
# ----> Processing batch 1000-1100 of 2083
# ----> Processing batch 1100-1200 of 2083
# ----> Processing batch 1200-1300 of 2083
# ----> Processing batch 1300-1400 of 2083
# ----> Processing batch 1400-1500 of 2083
# ----> Processing batch 1500-1600 of 2083
# ----> Processing batch 1600-1700 of 2083
# ----> Processing batch 1700-1800 of 2083
# ----> Processing batch 1800-1900 of 2083
# ----> Processing batch 1900-2000 of 2083
# ----> Processing batch 2000-2083 of 2083
# --> crunching on osm_on_golf_course, 2083 clusters
# ----> Processing batch 0-100 of 2083
# ----> Processing batch 100-200 of 2083
# ----> Processing batch 200-300 of 2083
# ----> Processing batch 300-400 of 2083
# ----> Processing batch 400-500 of 2083
# ----> Processing batch 500-600 of 2083
# ----> Processing batch 600-700 of 2083
# ----> Processing batch 700-800 of 2083
# ----> Processing batch 800-900 of 2083
# ----> Processing batch 900-1000 of 2083
# ----> Processing batch 1000-1100 of 2083
# ----> Processing batch 1100-1200 of 2083
# ----> Processing batch 1200-1300 of 2083
# ----> Processing batch 1300-1400 of 2083
# ----> Processing batch 1400-1500 of 2083
# ----> Processing batch 1500-1600 of 2083
# ----> Processing batch 1600-1700 of 2083
# ----> Processing batch 1700-1800 of 2083
# ----> Processing batch 1800-1900 of 2083
# ----> Processing batch 1900-2000 of 2083
# ----> Processing batch 2000-2083 of 2083
# Processing model group: single_family
# --> crunching on location, 107 clusters
# --> crunching on land_area_sqft, 155 clusters
# ----> Processing batch 0-100 of 155
# ----> Processing batch 100-155 of 155
# ----> 100/155, 65% clustering on WINSTON-GOVANS_AREA OF MINIMAL FLOOD HAZARD, field = land_area_sqft, size = 214
# --> crunching on geom_rectangularity_num, 238 clusters
# ----> Processing batch 0-100 of 238
# ----> Processing batch 100-200 of 238
# ----> 100/238, 42% clustering on THE ORCHARDS_AREA OF MINIMAL FLOOD HAZARD_242193.0, field = geom_rectangularity_num, size = 101
# ----> Processing batch 200-238 of 238
# ----> 200/238, 84% clustering on LAKELAND_AREA OF MINIMAL FLOOD HAZARD_4791.0, field = geom_rectangularity_num, size = 99
# --> crunching on geom_aspect_ratio, 388 clusters
# ----> Processing batch 0-100 of 388
# ----> Processing batch 100-200 of 388
# ----> 100/388, 26% clustering on CROSS COUNTRY_AREA OF MINIMAL FLOOD HAZARD_68824.0_0.8848836470378884, field = geom_aspect_ratio, size = 182
# ----> Processing batch 200-300 of 388
# ----> 200/388, 52% clustering on RADNOR-WINSTON_AREA OF MINIMAL FLOOD HAZARD_18948.0_0.9980709159409993, field = geom_aspect_ratio, size = 45
# ----> Processing batch 300-388 of 388
# ----> 300/388, 77% clustering on BEVERLY HILLS_AREA OF MINIMAL FLOOD HAZARD_7496.0_0.997619929888712, field = geom_aspect_ratio, size = 56
# --> crunching on elevation_mean, 656 clusters
# ----> Processing batch 0-100 of 656
# ----> Processing batch 100-200 of 656
# ----> Processing batch 200-300 of 656
# ----> Processing batch 300-400 of 656
# ----> Processing batch 400-500 of 656
# ----> Processing batch 500-600 of 656
# ----> Processing batch 600-656 of 656
# --> crunching on slope_mean, 656 clusters
# ----> Processing batch 0-100 of 656
# ----> Processing batch 100-200 of 656
# ----> Processing batch 200-300 of 656
# ----> Processing batch 300-400 of 656
# ----> Processing batch 400-500 of 656
# ----> Processing batch 500-600 of 656
# ----> Processing batch 600-656 of 656
# --> crunching on noise_mean, 656 clusters
# ----> Processing batch 0-100 of 656
# ----> Processing batch 100-200 of 656
# ----> Processing batch 200-300 of 656
# ----> Processing batch 300-400 of 656
# ----> Processing batch 400-500 of 656
# ----> Processing batch 500-600 of 656
# ----> Processing batch 600-656 of 656
# --> crunching on is_geom_complex, 656 clusters
# ----> Processing batch 0-100 of 656
# ----> Processing batch 100-200 of 656
# ----> Processing batch 200-300 of 656
# ----> 200/656, 30% clustering on <NA>_AREA OF MINIMAL FLOOD HAZARD, field = is_geom_complex, size = 20
# ----> Processing batch 300-400 of 656
# ----> 300/656, 46% clustering on WYNDHURST_AREA OF MINIMAL FLOOD HAZARD_107593.0_0.9846555780180316_5.1760709467093555, field = is_geom_complex, size = 22
# ----> Processing batch 400-500 of 656
# ----> 400/656, 61% clustering on KENILWORTH PARK_AREA OF MINIMAL FLOOD HAZARD_6747.0_0.9791032963142934_3.5432714643561574, field = is_geom_complex, size = 39
# ----> Processing batch 500-600 of 656
# ----> 500/656, 76% clustering on WALTHERSON_AREA OF MINIMAL FLOOD HAZARD_5720.0_0.9943108774394559_28.895918450423775, field = is_geom_complex, size = 240
# ----> Processing batch 600-656 of 656
# ----> 600/656, 91% clustering on WESTGATE_AREA OF MINIMAL FLOOD HAZARD_70567.0_0.9995927751859387_3.1972645051775386, field = is_geom_complex, size = 29
# --> crunching on is_geom_irregular, 657 clusters
# ----> Processing batch 0-100 of 657
# ----> Processing batch 100-200 of 657
# ----> 100/657, 15% clustering on ASHBURTON_AREA OF MINIMAL FLOOD HAZARD_6270.0_0.993954729423049_7.1346013170762195_0, field = is_geom_irregular, size = 109
# ----> Processing batch 200-300 of 657
# ----> 200/657, 30% clustering on REISTERSTOWN STATION_AREA OF MINIMAL FLOOD HAZARD_17600.0_0.8884944651552975_3.011674410278158_0, field = is_geom_irregular, size = 27
# ----> Processing batch 300-400 of 657
# ----> Processing batch 400-500 of 657
# ----> Processing batch 500-600 of 657
# ----> 500/657, 76% clustering on WALTHERSON_AREA OF MINIMAL FLOOD HAZARD_5720.0_0.906852497524386_213.53633720962597_0, field = is_geom_irregular, size = 241
# ----> Processing batch 600-657 of 657
# ----> 600/657, 91% clustering on WESTGATE_AREA OF MINIMAL FLOOD HAZARD_5824.0_0.9988333844639685_2.820671266941333_0, field = is_geom_irregular, size = 30
# --> crunching on osm_is_waterfront, 686 clusters
# ----> Processing batch 0-100 of 686
# ----> Processing batch 100-200 of 686
# ----> Processing batch 200-300 of 686
# ----> Processing batch 300-400 of 686
# ----> Processing batch 400-500 of 686
# ----> Processing batch 500-600 of 686
# ----> Processing batch 600-686 of 686
# --> crunching on osm_on_golf_course, 686 clusters
# ----> Processing batch 0-100 of 686
# ----> Processing batch 100-200 of 686
# ----> Processing batch 200-300 of 686
# ----> Processing batch 300-400 of 686
# ----> Processing batch 400-500 of 686
# ----> Processing batch 500-600 of 686
# ----> Processing batch 600-686 of 686
# Processing model group: commercial
# --> crunching on location, 263 clusters
# --> crunching on land_area_sqft, 398 clusters
# ----> Processing batch 0-100 of 398
# ----> Processing batch 100-200 of 398
# ----> 100/398, 25% clustering on MILTON-MONTFORD_AREA OF MINIMAL FLOOD HAZARD, field = land_area_sqft, size = 44
# ----> Processing batch 200-300 of 398
# ----> Processing batch 300-398 of 398
# --> crunching on geom_rectangularity_num, 515 clusters
# ----> Processing batch 0-100 of 515
# ----> Processing batch 100-200 of 515
# ----> Processing batch 200-300 of 515
# ----> 200/515, 39% clustering on COPPIN HEIGHTS/ASH-CO-EAST_AREA OF MINIMAL FLOOD HAZARD_155.82715102733175, field = geom_rectangularity_num, size = 101
# ----> Processing batch 300-400 of 515
# ----> 300/515, 58% clustering on ABELL_AREA OF MINIMAL FLOOD HAZARD_453.7899229541796, field = geom_rectangularity_num, size = 37
# ----> Processing batch 400-500 of 515
# ----> Processing batch 500-515 of 515
# --> crunching on geom_aspect_ratio, 670 clusters
# ----> Processing batch 0-100 of 670
# ----> Processing batch 100-200 of 670
# ----> Processing batch 200-300 of 670
# ----> Processing batch 300-400 of 670
# ----> Processing batch 400-500 of 670
# ----> Processing batch 500-600 of 670
# ----> Processing batch 600-670 of 670
# ----> 600/670, 90% clustering on BREWERS HILL_AREA OF MINIMAL FLOOD HAZARD_784.0_0.9948213783767892, field = geom_aspect_ratio, size = 39
# --> crunching on elevation_mean, 841 clusters
# ----> Processing batch 0-100 of 841
# ----> Processing batch 100-200 of 841
# ----> Processing batch 200-300 of 841
# ----> Processing batch 300-400 of 841
# ----> Processing batch 400-500 of 841
# ----> Processing batch 500-600 of 841
# ----> Processing batch 600-700 of 841
# ----> Processing batch 700-800 of 841
# ----> Processing batch 800-841 of 841
# --> crunching on slope_mean, 841 clusters
# ----> Processing batch 0-100 of 841
# ----> Processing batch 100-200 of 841
# ----> Processing batch 200-300 of 841
# ----> Processing batch 300-400 of 841
# ----> Processing batch 400-500 of 841
# ----> Processing batch 500-600 of 841
# ----> Processing batch 600-700 of 841
# ----> Processing batch 700-800 of 841
# ----> Processing batch 800-841 of 841
# --> crunching on noise_mean, 841 clusters
# ----> Processing batch 0-100 of 841
# ----> Processing batch 100-200 of 841
# ----> Processing batch 200-300 of 841
# ----> Processing batch 300-400 of 841
# ----> Processing batch 400-500 of 841
# ----> Processing batch 500-600 of 841
# ----> Processing batch 600-700 of 841
# ----> Processing batch 700-800 of 841
# ----> Processing batch 800-841 of 841
# --> crunching on is_geom_complex, 841 clusters
# ----> Processing batch 0-100 of 841
# ----> Processing batch 100-200 of 841
# ----> 100/841, 12% clustering on SETON HILL_AREA OF MINIMAL FLOOD HAZARD_733.0831957475347_0.9931017650374229_4.777353080104239, field = is_geom_complex, size = 16
# ----> Processing batch 200-300 of 841
# ----> Processing batch 300-400 of 841
# ----> 300/841, 36% clustering on UPPER FELLS POINT_AREA OF MINIMAL FLOOD HAZARD_3555.0_0.9951232128085004, field = is_geom_complex, size = 17
# ----> Processing batch 400-500 of 841
# ----> 400/841, 48% clustering on EDGEWOOD_AREA OF MINIMAL FLOOD HAZARD_27.941891839038263, field = is_geom_complex, size = 15
# ----> Processing batch 500-600 of 841
# ----> 500/841, 59% clustering on OLD GOUCHER_AREA OF MINIMAL FLOOD HAZARD_314.33362031633885_0.9913504275411522_13.757275250533803, field = is_geom_complex, size = 19
# ----> Processing batch 600-700 of 841
# ----> 600/841, 71% clustering on PIMLICO GOOD NEIGHBORS_AREA OF MINIMAL FLOOD HAZARD_370287.29684004333_0.9398971477649573, field = is_geom_complex, size = 18
# ----> Processing batch 700-800 of 841
# ----> 700/841, 83% clustering on WALTHERSON_AREA OF MINIMAL FLOOD HAZARD_1152.397630683483_0.9934704209709786_4.3299015068101845, field = is_geom_complex, size = 18
# ----> Processing batch 800-841 of 841
# ----> 800/841, 95% clustering on CURTIS BAY_AREA OF MINIMAL FLOOD HAZARD_39204000.0_0.9972969849543138_10.065797498777176, field = is_geom_complex, size = 17
# --> crunching on is_geom_irregular, 844 clusters
# ----> Processing batch 0-100 of 844
# ----> Processing batch 100-200 of 844
# ----> 100/844, 12% clustering on SETON HILL_AREA OF MINIMAL FLOOD HAZARD_733.0831957475347_0.9931017650374229_4.777353080104239_0, field = is_geom_irregular, size = 16
# ----> Processing batch 200-300 of 844
# ----> Processing batch 300-400 of 844
# ----> Processing batch 400-500 of 844
# ----> Processing batch 500-600 of 844
# ----> Processing batch 600-700 of 844
# ----> Processing batch 700-800 of 844
# ----> Processing batch 800-844 of 844
# --> crunching on osm_is_waterfront, 862 clusters
# ----> Processing batch 0-100 of 862
# ----> Processing batch 100-200 of 862
# ----> Processing batch 200-300 of 862
# ----> Processing batch 300-400 of 862
# ----> Processing batch 400-500 of 862
# ----> Processing batch 500-600 of 862
# ----> Processing batch 600-700 of 862
# ----> Processing batch 700-800 of 862
# ----> Processing batch 800-862 of 862
# --> crunching on osm_on_golf_course, 862 clusters
# ----> Processing batch 0-100 of 862
# ----> Processing batch 100-200 of 862
# ----> Processing batch 200-300 of 862
# ----> Processing batch 300-400 of 862
# ----> Processing batch 400-500 of 862
# ----> Processing batch 500-600 of 862
# ----> Processing batch 600-700 of 862
# ----> Processing batch 700-800 of 862
# ----> Processing batch 800-862 of 862
# Processing model group: industrial
# --> crunching on location, 78 clusters
# --> crunching on land_area_sqft, 134 clusters
# ----> Processing batch 0-100 of 134
# ----> Processing batch 100-134 of 134
# --> crunching on geom_rectangularity_num, 155 clusters
# ----> Processing batch 0-100 of 155
# ----> Processing batch 100-155 of 155
# --> crunching on geom_aspect_ratio, 178 clusters
# ----> Processing batch 0-100 of 178
# ----> Processing batch 100-178 of 178
# --> crunching on elevation_mean, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
# --> crunching on slope_mean, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
# --> crunching on noise_mean, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
# --> crunching on is_geom_complex, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
# ----> 100/190, 53% clustering on ORANGEVILLE_AREA OF MINIMAL FLOOD HAZARD_70899.08036738308_0.9946326414780484, field = is_geom_complex, size = 20
# --> crunching on is_geom_irregular, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
# --> crunching on osm_is_waterfront, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
# --> crunching on osm_on_golf_course, 190 clusters
# ----> Processing batch 0-100 of 190
# ----> Processing batch 100-190 of 190
#
# Marking IMPROVEMENT horizontal equity clusters...
# Processing model group: apartments
# --> crunching on bldg_area_finished_sqft, 1 clusters
# ----> Processing batch 0-1 of 1
# ----> 0/1, 0% clustering on , field = bldg_area_finished_sqft, size = 1745
# --> crunching on bldg_quality_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_condition_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_age_years, 2 clusters
# ----> Processing batch 0-2 of 2
# ----> 0/2, 0% clustering on _549545.9263103269, field = bldg_age_years, size = 872
# Processing model group: rowhome
# --> crunching on bldg_area_finished_sqft, 1 clusters
# ----> Processing batch 0-1 of 1
# ----> 0/1, 0% clustering on , field = bldg_area_finished_sqft, size = 171507
# --> crunching on bldg_quality_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_condition_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_age_years, 2 clusters
# ----> Processing batch 0-2 of 2
# ----> 0/2, 0% clustering on _1240.0, field = bldg_age_years, size = 85985
# Processing model group: single_family
# --> crunching on bldg_area_finished_sqft, 1 clusters
# ----> Processing batch 0-1 of 1
# ----> 0/1, 0% clustering on , field = bldg_area_finished_sqft, size = 39042
# --> crunching on bldg_quality_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_condition_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_age_years, 2 clusters
# ----> Processing batch 0-2 of 2
# ----> 0/2, 0% clustering on _1550.0, field = bldg_age_years, size = 19535
# Processing model group: commercial
# --> crunching on bldg_area_finished_sqft, 1 clusters
# ----> Processing batch 0-1 of 1
# ----> 0/1, 0% clustering on , field = bldg_area_finished_sqft, size = 20502
# --> crunching on bldg_quality_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_condition_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_age_years, 2 clusters
# ----> Processing batch 0-2 of 2
# ----> 0/2, 0% clustering on _2914.5446805171105, field = bldg_age_years, size = 10251
# Processing model group: industrial
# --> crunching on bldg_area_finished_sqft, 1 clusters
# ----> Processing batch 0-1 of 1
# ----> 0/1, 0% clustering on , field = bldg_area_finished_sqft, size = 2468
# --> crunching on bldg_quality_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_condition_num, 2 clusters
# ----> Processing batch 0-2 of 2
# --> crunching on bldg_age_years, 2 clusters
# ----> Processing batch 0-2 of 2
# ----> 0/2, 0% clustering on _2118635.5580736543, field = bldg_age_years, size = 1233

# %% [markdown]
# ## 5. Process sales
#
# We process sales validity information to set all the right codes for later use.
# We calculate time trends for sales over time to generate time-adjusted sale prices.

# %%
sales_univ_pair = from_checkpoint("2-clean-01-process_sales", process_sales,
    {
        "sup": sales_univ_pair,
        "settings": settings,
        "verbose": verbose
    }
)
# Out:
# Before univ merge len = 54124
# After univ merge len = 54124
# Using 54124 sales...
# --> 599 vacant sales
# --> 53525 improved sales
# --> 32735 valid for ratio study
# --> 599 valid for land ratio study
# len before hydrate = 54124
# len after hydrate = 54124
# len after enrich = 54124

# %% [markdown]
# ## 6. Scrutinize sales
#
# We cluster all sales of similar properties in similar locations.
# We flag individual sales that are anomalously high or low for their local cluster.
# This helps us catch potentially invalid sales that slipped by the assessor's notice.

# %%
sales_univ_pair = from_checkpoint("2-clean-02-mark-ss_ids", mark_ss_ids_per_model_group_sup,
    {
        "sup": sales_univ_pair,
        "settings": settings,
        "verbose": verbose,
    }
)
# Out:
# --> crunching on location, 61 clusters
# --> crunching on land_area_sqft, 61 clusters
# ----> Processing batch 0-61 of 61
# --> crunching on bldg_area_finished_sqft, 64 clusters
# ----> Processing batch 0-64 of 64
# --> crunching on bldg_quality_num, 65 clusters
# ----> Processing batch 0-65 of 65
# --> crunching on ['bldg_effective_age_years', 'bldg_age_years'], 65 clusters
# ----> Processing batch 0-65 of 65
# --> crunching on bldg_condition_num, 65 clusters
# ----> Processing batch 0-65 of 65
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/jb/s1bhbc2x3dgbhdvtbnz335sc0000gn/T/ipykernel_20022/2465474694.py", line 1, in <module>
#     sales_univ_pair = from_checkpoint("2-clean-02-mark-ss_ids", mark_ss_ids_per_model_group_sup,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/pipeline.py", line 653, in from_checkpoint
#     return openavmkit.checkpoint.from_checkpoint(path, func, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/checkpoint.py", line 16, in from_checkpoint
#     result = func(**params)
#              ^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/pipeline.py", line 593, in mark_ss_ids_per_model_group_sup
#     df_marked = mark_ss_ids_per_model_group(df_sales_hydrated, settings, verbose)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/sales_scrutiny_study.py", line 279, in mark_ss_ids_per_model_group
#     idx_high = df[sales_field].gt(df["high_thresh"])
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/utilities/data.py", line 167, in do_per_model_group
#     df_sub_updated = func(df_sub, **params_local)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/sales_scrutiny_study.py", line 302, in _mark_ss_ids
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/openavmkit/sales_scrutiny_study.py", line 255, in mark_sales_scrutiny_clusters
#     if "median" not in df:
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 778, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
sales_univ_pair = from_checkpoint("2-clean-03-sales-scrutiny", run_sales_scrutiny_per_model_group_sup,
    {
        "sup": sales_univ_pair,
        "settings": settings,
        "verbose": verbose
    }
)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sales_univ_pair = from_checkpoint("2-clean-03-sales-scrutiny", run_sales_scrutiny_per_model_group_sup,
#       2     {
#       3         "sup": sales_univ_pair,
#       4         "settings": settings,
#       5         "verbose": verbose
#       6     }
#       7 )
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/pipeline.py:653, in from_checkpoint(path, func, params)
#     639 def from_checkpoint(path: str, func: callable, params: dict) -> pd.DataFrame:
#     640    """
#     641    Wrapper function -- read cached data from a checkpoint file if it exists, otherwise run the specified function to
#     642    generate the data (and save it to a checkpoint file).
#    (...)
#     651    :rtype: pd.DataFrame
#     652    """
# --> 653    return openavmkit.checkpoint.from_checkpoint(path, func, params)
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/checkpoint.py:16, in from_checkpoint(path, func, params)
#      14   return read_checkpoint(path)
#      15 else:
# ---> 16   result = func(**params)
#      17   write_checkpoint(result, path)
#      18   return result
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/pipeline.py:632, in run_sales_scrutiny_per_model_group_sup(sup, settings, verbose)
#     618 """
#     619 Run sales scrutiny analysis for each model group within a SalesUniversePair. Assumes that the SalesUniversePair has
#     620 already been processed and marked with sales scrutiny ids.
#    (...)
#     629 :rtype: SalesUniversePair
#     630 """
#     631 df_sales_hydrated = get_hydrated_sales_from_sup(sup)
# --> 632 df_scrutinized = run_sales_scrutiny_per_model_group(df_sales_hydrated, settings, verbose)
#     633 sup.update_sales(df_scrutinized)
#     634 return sup
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/sales_scrutiny_study.py:353, in run_sales_scrutiny_per_model_group(df_in, settings, verbose)
#     351 def run_sales_scrutiny_per_model_group(df_in: pd.DataFrame, settings: dict, verbose=False) -> pd.DataFrame:
#     352   # Run sales scrutiny for each model group
# --> 353   df = do_per_model_group(df_in.copy(), settings, run_sales_scrutiny, {"settings": settings, "verbose": verbose}, key="key_sale")
#     354   return df
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/utilities/data.py:167, in do_per_model_group(df_in, settings, func, params, key, verbose)
#     164 df_sub = df.loc[mask].copy()
#     166 # Apply the function.
# --> 167 df_sub_updated = func(df_sub, **params_local)
#     169 if df_sub_updated is not None:
#     170   # Ensure consistent data types between df and the updated subset.
#     171   for col in df_sub_updated.columns:
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/sales_scrutiny_study.py:359, in run_sales_scrutiny(df_in, settings, model_group, verbose)
#     357 def run_sales_scrutiny(df_in: pd.DataFrame, settings: dict, model_group: str, verbose=False) -> pd.DataFrame:
#     358   # run sales validity:
# --> 359   ss = SalesScrutinyStudy(df_in, settings, model_group=model_group)
#     360   ss.write(f"out/sales_scrutiny/{model_group}")
#     362   # clean sales data:
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/sales_scrutiny_study.py:66, in SalesScrutinyStudy.__init__(self, df, settings, model_group)
#      64 df = stuff[key]
#      65 df, cluster_fields = mark_sales_scrutiny_clusters(df, settings)
# ---> 66 df["ss_id"] = key + "_" + df["ss_id"]
#      67 per_sqft = ""
#      68 denominator = ""
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:190, in OpsMixin.__radd__(self, other)
#     188 @unpack_zerodim_and_defer("__radd__")
#     189 def __radd__(self, other):
# --> 190     return self._arith_method(other, roperator.radd)
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/core/roperator.py:11, in radd(left, right)
#      10 def radd(left, right):
# ---> 11     return right + left
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U2'), dtype('float64')) -> None

# %% [markdown]
# # 7. Write out results

# %%
write_notebook_output_sup(sales_univ_pair, "2-clean")

# %% [markdown]
# # 8. Look at it on a map!
# - Take the files output in the previous step and put them in a map viewer like QGIS, ArcGIS, or Felt
# - Look at them with your eyeballs
# - Make sure the data looks correct
# - If not, go back and fix it!
# - Don't proceed to the next step until everything looks right
